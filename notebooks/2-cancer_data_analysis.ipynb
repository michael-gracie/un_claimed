# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/cancer_prop.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Orignating Account Number     object
# Payee                         object
# Payer Address                 object
# Amount                       float64
# Account Co Owner              object
# Payer FI                      object
# Type of Payment               object
# Date of Payment               object
# Date of BOC Transfer          object
# dtype: object

# %% [markdown]
# ## Looking at the highest value properties
#
# Looks like there are a few properties that have a high impact

# %%
df.sort_values(by = 'Amount', ascending = False)
# Out:
#      Unnamed: 0 Orignating Account Number  \
# 94            3          0000031321043785
# 95            4                   8105155
# 72            1                   5002285
# 15            4                   0000637
# 167           6              400061872729
# 99            8                   7001799
# 45            4                  24479036
# 66            5                   0000528
# 49            8          0000000026852276
# 289           8                  31716428
# 310           9          0000000038683149
# 56            5                  29566800
# 306           5          0000000037407517
# 303           2                  50484083
# 266           5                7696501624
# 245           4                    109161
# 215           4                  43393801
# 12            1                   9802268
# 96            5                   0310406
# 116           5                0296012571
# 117           6                0296012571
# ...

# %%
df.hist(bins=100, column='Amount')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1185270f0>]],
#       dtype=object)

# %%
df[df['Amount'].le(1000)].hist(bins=100, column='Amount')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1186a90f0>]],
#       dtype=object)

# %%
df['Amount'].describe()
# Out:
# count       311.000000
# mean        582.104084
# std        6854.055061
# min           5.000000
# 25%          25.000000
# 50%          50.000000
# 75%         103.500000
# max      119804.110000
# Name: Amount, dtype: float64
